# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
origin = pd.read_csv("dataset/softwares.csv")
origin
# Out:
#                                           name             release_date  \
# 0                            AR Fidget Spinner  2017-09-19 00:00:00.000
# 1                                  e-botfinder  2016-05-29 00:00:00.000
# 2                                       BioGlo  2018-01-06 00:00:00.000
# 3                                      Onsites  2018-02-09 00:00:00.000
# 4      Easylistr iOS - Twitter lists made easy  2016-06-01 00:00:00.000
# ...                                        ...                      ...
# 76817                              Tone Script  2021-03-19 00:00:00.000
# 76818  UI & UX Micro Tips: Ultimate Collection  2021-05-30 00:00:00.000
# 76819                                  ListKit  2021-09-08 00:00:00.000
# 76820                                 IdeaOnce  2021-09-28 00:00:00.000
# 76821                          Fantasy Startup  2021-12-09 00:00:00.000
#
#       product_of_the_day_date  product_ranking  upvotes  \
# 0                         NaN              NaN      134
# 1                         NaN              NaN      183
# 2                         NaN              NaN      196
# 3                  2018-02-09              4.0      315
# 4                         NaN              NaN      104
# ...                       ...              ...      ...
# 76817                     NaN              NaN       35
# 76818              2021-05-30              5.0      269
# 76819                     NaN              NaN      120
# 76820                     NaN              NaN      588
# 76821                     NaN              NaN      194
#
#                                            category_tags           hunter  \
# 0       ['IPAD', 'IPHONE', 'ARKIT', 'AUGMENTED REALITY']           shanev
# 1      ['BOTS', 'ARTIFICIAL INTELLIGENCE', 'TECH', 'S...  fabian_beringer
# 2      ['TECH', 'EDUCATION', 'CROWDFUNDING', 'HOME', ...     keegan_cooke
# 3      ['PRODUCTIVITY', 'USER EXPERIENCE', 'TECH', 'E...         _shahedk
# 4          ['TWITTER', 'PRODUCTIVITY', 'IPHONE', 'TECH']  igorbogdanovski
# ...                                                  ...              ...
# 76817  ['DESIGN TOOLS', 'GITHUB', 'WRITING TOOLS', 'T...    lance_pollard
# 76818  ['USER EXPERIENCE', 'DESIGN TOOLS', 'DESIGN BO...          mrcndrw
# 76819  ['GROWTH HACKING', 'MARKETING', 'GROWTH HACKS'...      alexgrayb2b
# 76820  ['DESIGN TOOLS', 'PRODUCTIVITY', 'MARKETING', ...     teamideaonce
# 76821                 ['EDUCATION', 'INVESTING', 'TECH']       gerryhays1
#
#                                                   makers  \
# 0                            ['shanev', 'tettoffensive']
# 1                                    ['fabian_beringer']
# 2                                       ['keegan_cooke']
# 3                                             ['jmtame']
# 4                                                     []
# ...                                                  ...
# 76817                                  ['lance_pollard']
# 76818                                        ['mrcndrw']
# 76819    ['alexgrayb2b', 'andre_b_haykal', 'bonnchri23']
# 76820                    ['teamideaonce', 'rayideaonce']
# 76821  ['gerryhays1', 'dan_devlin', 'akram_mnif', 'yo...
#
#                   last_updated
# 0      2022-01-11 01:34:10.874
# 1      2022-01-12 19:28:49.769
# 2      2022-01-11 09:00:59.413
# 3      2022-01-12 11:04:49.060
# 4      2022-01-12 14:52:25.118
# ...                        ...
# 76817  2022-01-14 15:02:19.010
# 76818  2022-01-14 15:02:20.097
# 76819  2022-01-14 15:02:21.797
# 76820  2022-01-14 15:02:21.905
# 76821  2022-01-14 15:02:31.688
#
# [76822 rows x 9 columns]

# %%
tags = origin["category_tags"].apply(lambda x: ' '.join(eval(x)))
tags
# Out:
# 0                      IPAD IPHONE ARKIT AUGMENTED REALITY
# 1        BOTS ARTIFICIAL INTELLIGENCE TECH SLACK MESSAGING
# 2              TECH EDUCATION CROWDFUNDING HOME BIOHACKING
# 3        PRODUCTIVITY USER EXPERIENCE TECH EMAIL HIRING...
# 4                         TWITTER PRODUCTIVITY IPHONE TECH
#                                ...
# 76817         DESIGN TOOLS GITHUB WRITING TOOLS TYPOGRAPHY
# 76818      USER EXPERIENCE DESIGN TOOLS DESIGN BOOKS BOOKS
# 76819          GROWTH HACKING MARKETING GROWTH HACKS SALES
# 76820    DESIGN TOOLS PRODUCTIVITY MARKETING SOCIAL MED...
# 76821                             EDUCATION INVESTING TECH
# Name: category_tags, Length: 76822, dtype: object

# %%
text = ' '.join(tags)
text
# Out:
# 'IPAD IPHONE ARKIT AUGMENTED REALITY BOTS ARTIFICIAL INTELLIGENCE TECH SLACK MESSAGING TECH EDUCATION CROWDFUNDING HOME BIOHACKING PRODUCTIVITY USER EXPERIENCE TECH EMAIL HIRING AND RECRUITING TWITTER PRODUCTIVITY IPHONE TECH TECH PRODUCTIVITY SAAS MARKETING DESIGN TOOLS SOCIAL MEDIA TOOLS PRODUCTIVITY USER EXPERIENCE MAC APPLE MUSIC WRITING TOOLS MAC TECH HOME IPAD IPHONE ANDROID GAMES TECH WEB APP SLACK TECH FUNNY WEB APP MAPS LINUX TECH MUSIC MEETINGS IPHONE APPLE WATCH TECH IPAD ANDROID SCIENCE BOOKS SPACE BOOKS DRONES INTERNET OF THINGS TECH DESIGN TOOLS TECH CHROME EXTENSIONS DEVELOPER TOOLS TECH WEB APP ANALYTICS DEVELOPER TOOLS FINTECH TECH WEB APP TECH PRODUCTIVITY IPHONE VIDEO STREAMING PHOTOGRAPHY INSTAGRAM MARKETING TECH ANDROID  MUSIC TECH ARTIFICIAL INTELLIGENCE TECH PS4 WII U GAMES XBOX ONE IPHONE IMESSAGE APPS GAMES EMAIL MARKETING SAAS MARKETING EMAIL SALES IPHONE VIDEO STREAMING TECH EMAIL MARKETING EMAIL NEWSLETTERS TECH EMAIL WEB APP DESIGN TOOLS PRODUCTIVITY DEVELOPER TOOLS TECH APIS FINTECH DEVELOPER TOOLS GITHUB OPEN SOURCE ANALYTICS DEVELOPER TOOLS TECH TECH PRODUCTIVITY TECH TASK MANAGEMENT EMAIL CALENDAR AND SCHEDULING SALES MESSAGING IPHONE TECH AUGMENTED REALITY IPAD ANDROID CHROME EXTENSIONS DESIGN TOOLS PRODUCTIVITY HIRING AND RECRUITING MARKETING AUGMENTED REALITY TECH PETS TECH HOME TRAVEL COFFEE COOKING WEB APP HIRING AND RECRUITING TECH TECH MUSIC TECH PRODUCTIVITY HARDWARE EDUCATION LEARN A LANGUAGE ARKIT AUGMENTED REALITY PRODUCTIVITY TECH APPLE ANDROID IPHONE MESSAGING PRODUCTIVITY CALENDAR AND SCHEDULING MAKER TOOLS OPEN SOURCE MARKETING INTERNET OF THINGS TECH TASK MANAGEMENT DESIGN TOOLS DEVELOPER TOOLS APPLE ANALYTICS WEB APP SOCIAL MEDIA TOOLS ANDROID SPREADSHEETS HARDWARE INTERNET OF THINGS TECH HOME BOOKS WEB APP NOMAD LIFESTYLE TRAVEL TECH SKATEBOARDING TECH PRODUCTIVITY DEVELOPER TOOLS TECH TECH WEB APP TELEGRAM TECH SAAS ARTIFICIAL INTELLIGENCE TECH PRODUCTIVITY WRITING TOOLS DEVELOPER TOOLS PRODUCTIVITY IPHONE USER EXPERIENCE TECH MUSIC TECH WEB APP TECH FINTECH VENTURE CAPITAL VIRTUAL REALITY TECH TECH AMAZON BOTS TECH DEVELOPER TOOLS ALEXA SKILLS MESSAGING TECH IPHONE TECH IPAD WEB APP ANDROID TECH WEB APP COOKING HEALTH AND FITNESS TECH HIRING AND RECRUITING SAAS WEB APP VIRTUAL REALITY PRODUCTIVITY FREELANCE PAYMENT TECH TECH PRODUCTIVITY TECH MAC MAC MENU BAR APPS DOGS PETS TECH PRODUCTIVITY MESSAGING TECH TECH PHOTOGRAPHY AUGMENTED REALITY TECH WINDOWS WEB APP MAC TECH TECH TECH IPHONE USER EXPERIENCE TECH MAC DEVELOPER TOOLS MAC MENU BAR APPS TECH FINTECH CRYPTO TECH DESIGN TOOLS USER EXPERIENCE MESSAGING TECH E-COMMERCE MEETINGS TECH EVENTS TRAVEL ANALYTICS MARKETING HEALTH AND FITNESS COOKING TECH PRODUCTIVITY EMAIL CHROME EXTENSIONS TASK MANAGEMENT  TECH PRODUCTIVITY WRITING TOOLS SAAS TECH MUSIC HARDWARE TECH WEB APP E-COMMERCE CHROME EXTENSIONS HOME TECH CARD GAMES WEB APP TECH GAMES WEB APP TECH BASEBALL TECH TECH DESIGN TOOLS DEVELOPER TOOLS TECH WINDOWS IPHONE TECH MAC EMAIL ANDROID MESSAGING TECH  SCIENCE BOOKS BOOKS TECH TECH AMAZON TECH SPOTIFY MUSIC ALEXA SKILLS SCIENCE BOOKS VIDEO STREAMING PHOTOGRAPHY TECH HISTORY BOOKS WEB APP PRODUCTIVITY SAAS TECH TASK MANAGEMENT ANALYTICS WEB APP WEB APP NEWS TECH VENTURE CAPITAL GAMES WRITING TOOLS PRIVACY SALES WRITING TOOLS MARKETING IPAD IPHONE TECH GIFS IPHONE ANDROID GAMES FREE GAMES TECH MARKETING GROWTH HACKING HARDWARE INTERNET OF THINGS TECH SOFTWARE ENGINEERING EDUCATION PROTOTYPING HOME INTERNET OF THINGS TECH TECH IPHONE HEALTH AND FITNESS TRAVEL TECH CHROME EXTENSIONS PRODUCTIVITY TECH HARDWARE DESIGN TOOLS BATTERIES TECH IPHONE E-COMMERCE CROWDFUNDING CARS HOME FUNNY MUSIC VIDEO STREAMING PAYMENT TRAVEL TECH CRYPTO TECH APPLE SOCIAL MEDIA TOOLS ANDROID MESSAGING TECH HIRING AND RECRUITING IPHONE TECH FACEBOOK TECH EMAIL EMAIL MARKETING TECH WINDOWS IPHONE WII U MAC IPAD PS4 XBOX ONE GAMES ANDROID LINUX 3DS PRODUCTIVITY BRANDING TECH TECH DESIGN TOOLS PROTOTYPING DEVELOPER TOOLS VIRTUAL REALITY GOOGLE GOOGLE ...

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
